# %% [markdown]
# # Writing tests
#
# In the previous notebook you became familiar with the assert statement.
# Assert statements are a way of quickly checking if a certain snippet of code returns the expected output.
#
# Sometimes, you want to be able to quickly run a script to check if your code is working correctly. In such cases you will want to create some kind of test file. You have probably noticed that the PAs often have a `.py` file with some tests in it. We will flip the switch in this notebook. We have provided you with a corrected and updated version of the function `max_even_square` from last week. Now write a test for it!
#
# It is helpful to read the book chapter on testing before attempting this notebook.

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; width:95%; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
#
# <b>Task 1:</b>
#
# Install the `testbook package` into your `mude-base` environment.
# You can do this easily by:
#
# - Opening Anaconda navigator
# - type in `conda activate mude-base`
# - type in `pip install testbook`
#
# **Task 2:**
#
# Edit the file `my_test.py` and create a test for the code below.
# The test should:
#
# - return the message 'not a list' when non-list objects, such as `'apple'`, are passed into the function
# - return the message 'only integers are allowed' when lists with non-integer values, such as `[1, 3, 'apple']` are passed into the function
# - return the message 'no even numbers found' when a list without any even numbers, such as `[1, 3, 5]`, are passed into the function
# - nothing happens if you pass a valid list with at least one even number in the function
#
# </p>
# </div>

# %%
def max_even_square(nums):
    if not isinstance(nums, (list, tuple)):
        raise TypeError("not a list")
    
    max_num = None

    for n in nums:
        if not isinstance(n, int):
            raise TypeError("only integers are allowed")
        if n % 2 == 0:
            if max_num is None or n > max_num:
                max_num = n
    
    if max_num is None:
        raise ValueError("no even numbers found")
    
    return max_num ** 2
