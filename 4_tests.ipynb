# %% [markdown]
# <div style="background-color:#AABAB2; color: black; width:95%; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
#
# **Task 1:**
#
# Create a test for the code below.
# The test should:
#
# - nothing happens if you pass a valid list with at least one even number in the function
# - return an error when a list without any even numbers, such as `[1, 3, 5]`, are passed into the function
# - return an error when when non-list objects, such as `'apple'`, are passed into the function
# - return an error when lists with non-integer values, such as `[1, 3, 'apple']` are passed into the function
# - retunr an error if an empty list is passed into the function
#
# Make sure your test in the cell is underneath the code for the function `max_even_squared` and that your whole test is in this cell.
#
# </p>
# </div>

# %%
# Out:
# test_empty_list (__main__.TestMaxEvenSquare.test_empty_list) ... ok
# test_no_even_numbers (__main__.TestMaxEvenSquare.test_no_even_numbers) ... ok
# test_non_integer_in_list (__main__.TestMaxEvenSquare.test_non_integer_in_list) ... ok
# test_non_list_input (__main__.TestMaxEvenSquare.test_non_list_input) ... ok
# test_regular_case (__main__.TestMaxEvenSquare.test_regular_case) ... ok
# test_single_even (__main__.TestMaxEvenSquare.test_single_even) ... ok
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.017s
#
# OK

# %%
import unittest

class TestMaxEvenSquare(unittest.TestCase):

    def test_regular_case(self):
        self.assertEqual(max_even_square([1, 2, 3, 4]), 16)

    def test_no_even_numbers(self):
        with self.assertRaisesRegex(ValueError, "no even numbers found"):
            max_even_square([1, 3, 5])

    def test_not_a_list(self):
        with self.assertRaisesRegex(TypeError, "not a list"):
            max_even_square("apple")

    def test_non_integer_in_list(self):
        with self.assertRaisesRegex(TypeError, "only integers are allowed"):
            max_even_square([1, 2, "apple"])

    def test_empty_list(self):
        with self.assertRaisesRegex(ValueError, "no even numbers found"):
            max_even_square([])

# Run the tests in the notebook
unittest.main(argv=['first-arg-is-ignored'], verbosity=2, exit=False)
# Out:
# test_empty_list (__main__.TestMaxEvenSquare.test_empty_list) ... ok
# test_no_even_numbers (__main__.TestMaxEvenSquare.test_no_even_numbers) ... ok
# test_non_integer_in_list (__main__.TestMaxEvenSquare.test_non_integer_in_list) ... ok
# test_not_a_list (__main__.TestMaxEvenSquare.test_not_a_list) ... ok
# test_regular_case (__main__.TestMaxEvenSquare.test_regular_case) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.018s
#
# OK
